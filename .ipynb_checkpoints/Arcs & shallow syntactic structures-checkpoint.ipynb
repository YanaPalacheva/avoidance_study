# %%
import pandas as pd
import os
from convokit import Corpus 

corpus_all = Corpus(os.getcwd()+'\\Annotated\\full-avoidance-corpus')
corpus_avoidance = Corpus(os.getcwd()+'\\Annotated\\avoidance-corpus')
corpus_fight = Corpus(os.getcwd()+'\\Annotated\\fight-corpus')
corpus_flight = Corpus(os.getcwd()+'\\Annotated\\flight-corpus')

# %%
utt = corpus_avoidance.random_utterance()
utt.retrieve_meta('parsed')
# Out:
# [{'rt': 43,
#   'toks': [{'tok': 'In', 'tag': 'IN', 'dep': 'prep', 'up': 43, 'dn': [1]},
#    {'tok': 'view', 'tag': 'NN', 'dep': 'pobj', 'up': 0, 'dn': [2]},
#    {'tok': 'of', 'tag': 'IN', 'dep': 'prep', 'up': 1, 'dn': [4]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 4, 'dn': []},
#    {'tok': 'praise', 'tag': 'NN', 'dep': 'pobj', 'up': 2, 'dn': [3, 8]},
#    {'tok': 'that', 'tag': 'WDT', 'dep': 'nsubjpass', 'up': 8, 'dn': []},
#    {'tok': 'has', 'tag': 'VBZ', 'dep': 'aux', 'up': 8, 'dn': []},
#    {'tok': 'been', 'tag': 'VBN', 'dep': 'auxpass', 'up': 8, 'dn': []},
#    {'tok': 'heaped',
#     'tag': 'VBN',
#     'dep': 'relcl',
#     'up': 4,
#     'dn': [5, 6, 7, 9, 11, 14, 30]},
#    {'tok': 'on', 'tag': 'IN', 'dep': 'prep', 'up': 8, 'dn': [10]},
#    {'tok': 'Glasgow', 'tag': 'NNP', 'dep': 'pobj', 'up': 9, 'dn': []},
#    {'tok': 'in', 'tag': 'IN', 'dep': 'prep', 'up': 8, 'dn': [13]},
#    {'tok': 'recent', 'tag': 'JJ', 'dep': 'amod', 'up': 13, 'dn': []},
#    {'tok': 'months', 'tag': 'NNS', 'dep': 'pobj', 'up': 11, 'dn': [12]},
#    {'tok': 'by', 'tag': 'IN', 'dep': 'agent', 'up': 8, 'dn': [16]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 16, 'dn': []},
#    {'tok': 'Minister',
#     'tag': 'NNP',
#     'dep': 'pobj',
#     'up': 14,
#     'dn': [15, 17, 19]},
#    {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 16, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 19, 'dn': []},
#    {'tok': 'Secretary',
#     'tag': 'NNP',
#     'dep': 'appos',
#     'up': 16,
#     'dn': [18, 20, 22, 26, 29]},
#    {'tok': 'of', 'tag': 'IN', 'dep': 'prep', 'up': 19, 'dn': [21]},
#    {'tok': 'State', 'tag': 'NNP', 'dep': 'pobj', 'up': 20, 'dn': []},
#    {'tok': 'for', 'tag': 'IN', 'dep': 'prep', 'up': 19, 'dn': [23]},
#    {'tok': 'Trade', 'tag': 'NNP', 'dep': 'pobj', 'up': 22, 'dn': [24, 25]},
#    {'tok': 'and', 'tag': 'CC', 'dep': 'cc', 'up': 23, 'dn': []},
#    {'tok': 'Industry', 'tag': 'NNP', 'dep': 'conj', 'up': 23, 'dn': []},
#    {'tok': 'and', 'tag': 'CC', 'dep': 'cc', 'up': 19, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 29, 'dn': []},
#    {'tok': 'Prime', 'tag': 'NNP', 'dep': 'compound', 'up': 29, 'dn': []},
#    {'tok': 'Minister', 'tag': 'NNP', 'dep': 'conj', 'up': 19, 'dn': [27, 28]},
#    {'tok': 'regarding', 'tag': 'VBG', 'dep': 'prep', 'up': 8, 'dn': [33]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 33, 'dn': []},
#    {'tok': 'GEAR', 'tag': 'NNP', 'dep': 'compound', 'up': 33, 'dn': []},
#    {'tok': 'project',
#     'tag': 'NN',
#     'dep': 'pobj',
#     'up': 30,
#     'dn': [31, 32, 34, 38]},
#    {'tok': 'and', 'tag': 'CC', 'dep': 'cc', 'up': 33, 'dn': []},
#    {'tok': 'inner', 'tag': 'JJ', 'dep': 'amod', 'up': 37, 'dn': []},
#    {'tok': '-', 'tag': 'HYPH', 'dep': 'punct', 'up': 37, 'dn': []},
#    {'tok': 'city', 'tag': 'NN', 'dep': 'compound', 'up': 38, 'dn': [35, 36]},
#    {'tok': 'improvement', 'tag': 'NN', 'dep': 'conj', 'up': 33, 'dn': [37]},
#    {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 43, 'dn': []},
#    {'tok': 'will', 'tag': 'MD', 'dep': 'aux', 'up': 43, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 42, 'dn': []},
#    {'tok': 'Chancellor', 'tag': 'NNP', 'dep': 'nsubj', 'up': 43, 'dn': [41]},
#    {'tok': 'take', 'tag': 'VB', 'dep': 'ROOT', 'dn': [0, 39, 40, 42, 45, 93]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 45, 'dn': []},
#    {'tok': 'opportunity',
#     'tag': 'NN',
#     'dep': 'dobj',
#     'up': 43,
#     'dn': [44, 47]},
#    {'tok': 'to', 'tag': 'TO', 'dep': 'aux', 'up': 47, 'dn': []},
#    {'tok': 'pay', 'tag': 'VB', 'dep': 'acl', 'up': 45, 'dn': [46, 49, 50]},
#    {'tok': 'due', 'tag': 'JJ', 'dep': 'amod', 'up': 49, 'dn': []},
#    {'tok': 'credit', 'tag': 'NN', 'dep': 'dobj', 'up': 47, 'dn': [48]},
#    {'tok': 'to', 'tag': 'IN', 'dep': 'prep', 'up': 47, 'dn': [53]},
#    {'tok': 'my', 'tag': 'PRP$', 'dep': 'poss', 'up': 53, 'dn': []},
#    {'tok': 'right', 'tag': 'NN', 'dep': 'amod', 'up': 53, 'dn': []},
#    {'tok': 'hon',
#     'tag': 'NN',
#     'dep': 'pobj',
#     'up': 50,
#     'dn': [51, 52, 54, 57, 67]},
#    {'tok': 'Friend', 'tag': 'NNP', 'dep': 'appos', 'up': 53, 'dn': [56]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 56, 'dn': []},
#    {'tok': 'Member', 'tag': 'NNP', 'dep': 'appos', 'up': 54, 'dn': [55]},
#    {'tok': 'for', 'tag': 'IN', 'dep': 'prep', 'up': 53, 'dn': [58]},
#    {'tok': 'Glasgow',
#     'tag': 'NNP',
#     'dep': 'pobj',
#     'up': 57,
#     'dn': [59, 60, 65]},
#    {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 58, 'dn': []},
#    {'tok': 'Govan',
#     'tag': 'NNP',
#     'dep': 'appos',
#     'up': 58,
#     'dn': [61, 63, 64]},
#    {'tok': '(', 'tag': '-LRB-', 'dep': 'punct', 'up': 60, 'dn': []},
#    {'tok': 'Mr.', 'tag': 'NNP', 'dep': 'compound', 'up': 63, 'dn': []},
#    {'tok': 'Millan', 'tag': 'NNP', 'dep': 'appos', 'up': 60, 'dn': [62]},
#    {'tok': ')', 'tag': '-RRB-', 'dep': 'punct', 'up': 60, 'dn': []},
#    {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 58, 'dn': []},
#    {'tok': 'who', 'tag': 'WP', 'dep': 'nsubj', 'up': 67, 'dn': []},
#    {'tok': 'instituted',
#     'tag': 'VBD',
#     'dep': 'relcl',
#     'up': 53,
#     'dn': [66, 69, 74]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 69, 'dn': []},
#    {'tok': 'scheme', 'tag': 'NN', 'dep': 'dobj', 'up': 67, 'dn': [68, 70]},
#    {'tok': 'for', 'tag': 'IN', 'dep': 'prep', 'up': 69, 'dn': [71]},
#    {'tok': 'GEAR', 'tag': 'NNP', 'dep': 'pobj', 'up': 70, 'dn': []},
#    {'tok': 'when', 'tag': 'WRB', 'dep': 'advmod', 'up': 74, 'dn': []},
#    {'tok': 'he', 'tag': 'PRP', 'dep': 'nsubj', 'up': 74, 'dn': []},
#    {'tok': 'was', 'tag': 'VBD', 'dep': 'advcl', 'up': 67, 'dn': [72, 73, 75]},
#    {'tok': 'Secretary',
#     'tag': 'NNP',
#     'dep': 'attr',
#     'up': 74,
#     'dn': [76, 78, 85]},
#    {'tok': 'of', 'tag': 'IN', 'dep': 'prep', 'up': 75, 'dn': [77]},
#    {'tok': 'State', 'tag': 'NNP', 'dep': 'pobj', 'up': 76, 'dn': []},
#    {'tok': ',', 'tag': ',', 'dep': 'punct', 'up': 75, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 85, 'dn': []},
#    {'tok': 'Labour', 'tag': 'NNP', 'dep': 'npadvmod', 'up': 82, 'dn': []},
#    {'tok': '-', 'tag': 'HYPH', 'dep': 'punct', 'up': 82, 'dn': []},
#    {'tok': 'controlled',
#     'tag': 'VBN',
#     'dep': 'amod',
#     'up': 85,
#     'dn': [80, 81]},
#    {'tok': 'Glasgow', 'tag': 'NNP', 'dep': 'compound', 'up': 85, 'dn': []},
#    {'tok': 'district', 'tag': 'NN', 'dep': 'compound', 'up': 85, 'dn': []},
#    {'tok': 'council',
#     'tag': 'NN',
#     'dep': 'conj',
#     'up': 75,
#     'dn': [79, 82, 83, 84, 86, 92]},
#    {'tok': 'and', 'tag': 'CC', 'dep': 'cc', 'up': 85, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 92, 'dn': []},
#    {'tok': 'Labour', 'tag': 'NNP', 'dep': 'npadvmod', 'up': 90, 'dn': []},
#    {'tok': '-', 'tag': 'HYPH', 'dep': 'punct', 'up': 90, 'dn': []},
#    {'tok': 'controlled',
#     'tag': 'VBN',
#     'dep': 'amod',
#     'up': 92,
#     'dn': [88, 89]},
#    {'tok': 'Strathclyde', 'tag': 'NNP', 'dep': 'compound', 'up': 92, 'dn': []},
#    {'tok': 'region', 'tag': 'NN', 'dep': 'conj', 'up': 85, 'dn': [87, 90, 91]},
#    {'tok': '?', 'tag': '.', 'dep': 'punct', 'up': 43, 'dn': []}]},
#  {'rt': 0,
#   'toks': [{'tok': 'Is', 'tag': 'VBZ', 'dep': 'ROOT', 'dn': [1, 3, 38]},
#    {'tok': 'not', 'tag': 'RB', 'dep': 'neg', 'up': 0, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 3, 'dn': []},
#    {'tok': 'lesson',
#     'tag': 'NN',
#     'dep': 'attr',
#     'up': 0,
#     'dn': [2, 4, 6, 8, 19]},
#    {'tok': 'of', 'tag': 'IN', 'dep': 'prep', 'up': 3, 'dn': [5]},
#    {'tok': 'Glasgow', 'tag': 'NNP', 'dep': 'pobj', 'up': 4, 'dn': []},
#    {'tok': 'and', 'tag': 'CC', 'dep': 'cc', 'up': 3, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 8, 'dn': []},
#    {'tok': 'improvements',
#     'tag': 'NNS',
#     'dep': 'conj',
#     'up': 3,
#     'dn': [7, 12]},
#    {'tok': 'that', 'tag': 'WDT', 'dep': 'nsubjpass', 'up': 12, 'dn': []},
#    {'tok': 'have', 'tag': 'VBP', 'dep': 'aux', 'up': 12, 'dn': []},
#    {'tok': 'been', 'tag': 'VBN', 'dep': 'auxpass', 'up': 12, 'dn': []},
#    {'tok': 'carried',
#     'tag': 'VBN',
#     'dep': 'relcl',
#     'up': 8,
#     'dn': [9, 10, 11, 13, 14]},
#    {'tok': 'out', 'tag': 'RP', 'dep': 'prt', 'up': 12, 'dn': []},
#    {'tok': 'there', 'tag': 'RB', 'dep': 'advmod', 'up': 12, 'dn': []},
#    {'tok': 'that', 'tag': 'WDT', 'dep': 'mark', 'up': 19, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 17, 'dn': []},
#    {'tok': 'Government', 'tag': 'NNP', 'dep': 'nsubj', 'up': 19, 'dn': [16]},
#    {'tok': 'should', 'tag': 'MD', 'dep': 'aux', 'up': 19, 'dn': []},
#    {'tok': 'give',
#     'tag': 'VB',
#     'dep': 'relcl',
#     'up': 3,
#     'dn': [15, 17, 18, 21, 31]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 21, 'dn': []},
#    {'tok': 'resources',
#     'tag': 'NNS',
#     'dep': 'dobj',
#     'up': 19,
#     'dn': [20, 22, 24]},
#    {'tok': 'and', 'tag': 'CC', 'dep': 'cc', 'up': 21, 'dn': []},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 24, 'dn': []},
#    {'tok': 'powers', 'tag': 'NNS', 'dep': 'conj', 'up': 21, 'dn': [23]},
#    {'tok': 'to', 'tag': 'IN', 'dep': 'aux', 'up': 27, 'dn': []},
#    {'tok': 'locally', 'tag': 'RB', 'dep': 'advmod', 'up': 27, 'dn': []},
#    {'tok': 'elected', 'tag': 'VBN', 'dep': 'amod', 'up': 31, 'dn': [25, 26]},
#    {'tok': 'Labour', 'tag': 'NNP', 'dep': 'npadvmod', 'up': 30, 'dn': []},
#    {'tok': '-', 'tag': 'HYPH', 'dep': 'punct', 'up': 30, 'dn': []},
#    {'tok': 'controlled',
#     'tag': 'VBN',
#     'dep': 'amod',
#     'up': 31,
#     'dn': [28, 29]},
#    {'tok': 'authorities',
#     'tag': 'NNS',
#     'dep': 'dobj',
#     'up': 19,
#     'dn': [27, 30, 33]},
#    {'tok': 'to', 'tag': 'TO', 'dep': 'aux', 'up': 33, 'dn': []},
#    {'tok': 'get', 'tag': 'VB', 'dep': 'relcl', 'up': 31, 'dn': [32, 34, 35]},
#    {'tok': 'on', 'tag': 'RP', 'dep': 'prt', 'up': 33, 'dn': []},
#    {'tok': 'with', 'tag': 'IN', 'dep': 'prep', 'up': 33, 'dn': [37]},
#    {'tok': 'the', 'tag': 'DT', 'dep': 'det', 'up': 37, 'dn': []},
#    {'tok': 'job', 'tag': 'NN', 'dep': 'pobj', 'up': 35, 'dn': [36]},
#    {'tok': '?', 'tag': '.', 'dep': 'punct', 'up': 0, 'dn': []}]}]

# %%
from convokit.text_processing import TextProcessor
from nltk.corpus import stopwords
STOPWORDS = stopwords.words("english")

class RemoveStopWords(TextProcessor):
	"""
		Transformer 

		:param output_field: name of attribute to output to.
		:param input_field: name of field to use as input. defaults to 'parsed', which stores dependency parses as returned by the TextParser transformer; otherwise expects similarly-formatted input.
		:param input_filter: a boolean function of signature `input_filter(utterance, aux_input)`. parses will only be computed for utterances where `input_filter` returns `True`. By default, will always return `True`, meaning that arcs will be computed for all utterances.
		:param verbosity: frequency of status messages.
	"""

	def __init__(self, output_field, input_field='parsed', input_filter=None, verbosity=0):
		TextProcessor.__init__(self, censor_stopwords, 
			output_field=output_field, input_field=input_field,
			input_filter=input_filter, verbosity=verbosity)

def _is_stopword(tok):
	return tok['tok'].lower() in STOPWORDS

# def _get_w_det(tok, sent):

# 	if tok['tag'].startswith('W'): return tok['tok']
# 	if len(tok['dn']) == 0: return False
# 	first_tok = sent['toks'][tok['dn'][0]]
# 	if first_tok['tag'].startswith('W'): return first_tok['tok']
# 	return False

def _convert_stopword(tok, sent):
	if _is_stopword(tok):
# 		has_w = _get_w_det(tok, sent)
# 		if has_w:
# 			return has_w.lower()
# 		else:
		return 'STOPWORD'
	return tok['tok'].lower()

def censor_stopwords(text_entry):
	"""
		Stand-alone function that removes stopwords from parsed text.

		:param text_entry: parsed text
		:return: parse with stopwords censored out.
	"""

	sents = []
	for raw_sent in text_entry:
		sent = {'rt': raw_sent['rt'], 'toks': []}
		for raw_tok in raw_sent['toks']:
			tok = {k: raw_tok[k] for k in ['dep','dn','tag']}
			if 'up' in raw_tok: tok['up'] = raw_tok['up']
			tok['tok'] = _convert_stopword(raw_tok, raw_sent)
			sent['toks'].append(tok)
		sents.append(sent)
	return sents

# %%
remove_stopwords = RemoveStopWords('parsed_cleaned', input_field='parsed', verbosity=100)
corpus_fight_cl = remove_stopwords.transform(corpus_fight)

from convokit.text_processing import TextToArcs
get_cleaned_arcs = TextToArcs('arcs_cleaned', input_field='parsed_cleaned', verbosity=100)
corpus_fight_xxx = get_cleaned_arcs.transform(corpus_fight_cl)

utt_cl = corpus_fight_xxx.random_utterance()
utt_cl.retrieve_meta('arcs_cleaned')
# Out:
# 038/038 utterances processed
# 038/038 utterances processed
# ['crazy_* drives_* drives_faster drives_stopword everyone>* everyone>stopword everyone_* everyone_drives faster_* stopword_* stopword_crazy',
#  'drives_* drives_slower drives_stopword everyone>* everyone>stopword everyone_* everyone_drives idiot_* idiot_stopword slower_* slower_stopword stopword_* stopword_idiot',
#  'argument_* argument_stopword different_* different_stopword stopword>* stopword_* stopword_argument stopword_different']

# %%
utt_cl.text
# Out:
# 'Everyone who drives faster than you is crazy. Everyone who drives slower than you is an idiot.\n\nThis argument is no different.'

# %%
arcs = utt_cl.retrieve_meta('arcs_cleaned')
spl_arcs = [arc.split(' ') for arc in arcs]
new_arcs = []
for arc in spl_arcs:
    print(arc)
    a = [subarc for subarc in arc if 'stopword' not in subarc and '*' not in subarc ]
    if a:
        new_arcs.append(a)
    print(a)
new_arcs
#     for ind, subarc in enumerate(arc):
#         if 'stopword' in subarc or '*' in subarc:
#         arc.re    
# 'stopword', '\*'
# Out:
# ['crazy_*', 'drives_*', 'drives_faster', 'drives_stopword', 'everyone>*', 'everyone>stopword', 'everyone_*', 'everyone_drives', 'faster_*', 'stopword_*', 'stopword_crazy']
# ['drives_faster', 'everyone_drives']
# ['drives_*', 'drives_slower', 'drives_stopword', 'everyone>*', 'everyone>stopword', 'everyone_*', 'everyone_drives', 'idiot_*', 'idiot_stopword', 'slower_*', 'slower_stopword', 'stopword_*', 'stopword_idiot']
# ['drives_slower', 'everyone_drives']
# ['argument_*', 'argument_stopword', 'different_*', 'different_stopword', 'stopword>*', 'stopword_*', 'stopword_argument', 'stopword_different']
# []
# [['drives_faster', 'everyone_drives'], ['drives_slower', 'everyone_drives']]

# %%
print(STOPWORDS)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
STOPWORDS_NEW = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 
                 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 
                 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 
                 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 
                 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'or', 
                 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'between', 'into', 'through', 
                 'during', 'before', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 
                 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 
                 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 's', 'will', 'just', 'should', 'll', 'm', 'o', 
                 're', 'y', 'ma']
