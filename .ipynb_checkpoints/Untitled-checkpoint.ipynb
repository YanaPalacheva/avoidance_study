# %% [markdown]
# ## Convokit's motifs

# %%
import pandas as pd

# df_fight = pd.read_csv("Annotated\\Avoidance_annotated_avoided_fight.csv")
# df_pqtc = df_fight[df_fight["dataset"] == 'PQTC']
# df_pqtc.head()
# ids = df_pqtc['id_a'] + df_pqtc['id_q']

# %%
df_pqm = pd.read_csv('pmq_metadata.tsv', sep="\t")

# %%
df_pqm.head()
# Out:
#      pair_idx                                      question_text  \
# 0  Thatcher.0  rose— Welcome back. Mr. Callaghan I understand...
# 1  Thatcher.1  I realise that the right hon Lady is having a ...
# 2  Thatcher.2  rose— rose— Mr. Callaghan I understand, Mr. Sp...
# 3  Thatcher.3  As the Prime Minister depends so much on her m...
# 4  Thatcher.4  With reference to that last answer, may I assu...
#
#   question_text_idx                                        answer_text  \
# 0      Thatcher.0.q  I understand the scheme which the right hon. G...
# 1      Thatcher.1.q  The right hon. Gentleman knows that we can nev...
# 2      Thatcher.2.q  The right hon. Gentleman knows that the unwise...
# 3      Thatcher.3.q  I wish that this country created enough wealth...
# 4      Thatcher.4.q  There was no linkage between the negotiations ...
#
#   answer_text_idx                asker  answerer asker_party answerer_party  \
# ...
